# %% [markdown]
# <h1 style = "color : Brown">Pandas</h1>
#
# <h4 style = "color : Green">pip install pandas</h4>

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Churn_Modelling.csv')
#df = pd.read_excel('xyz.xlsx', sheet_name = 'Page 1')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.tail(10)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
# 9999      10000    15628319       Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Describe the statistical information of the numerical columns
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Prints all the columns of the dataframe

df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# Transpose 

df.T
# Out:
#                      0         1         2         3         4         5     \
# RowNumber               1         2         3         4         5         6
# CustomerId       15634602  15647311  15619304  15701354  15737888  15574012
# Surname          Hargrave      Hill      Onio      Boni  Mitchell       Chu
# CreditScore           619       608       502       699       850       645
# Geography          France     Spain    France    France     Spain     Spain
# Gender             Female    Female    Female    Female    Female      Male
# Age                    42        41        42        39        43        44
# Tenure                  2         1         8         1         2         8
# Balance                 0   83807.9    159661         0    125511    113756
# NumOfProducts           1         1         3         2         1         2
# HasCrCard               1         0         1         0         1         1
# ...

# %%
#Sort your dataframe based on Age

df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
new_df = df.sort_values('Age')
new_df.head(5)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 3512       3       0.00              2          1               1
# 1678       4   82767.42              1          1               0
# 3517       1       0.00              2          0               0
# 9520       2   93816.70              2          1               0
# 2021       3  128743.80              1          0               0
#
#       EstimatedSalary  Exited
# 3512         86994.54       0
# 1678         71811.90       0
# ...

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['New Balance'] = df['Balance'] + 1000

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  New Balance
# 0        101348.88       1      1000.00
# 1        112542.58       0     84807.86
# ...

# %%
df['New Balance']
# Out:
# 0         1000.00
# 1        84807.86
# 2       160660.80
# 3         1000.00
# 4       126510.82
#           ...
# 9995      1000.00
# 9996     58369.61
# 9997      1000.00
# 9998     76075.31
# 9999    131142.79
# Name: New Balance, Length: 10000, dtype: float64

# %%
df['Random Column'] = 'Good Day'
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  New Balance Random Column
# 0        101348.88       1      1000.00      Good Day
# ...

# %%
# How to access your rows

df[20:26]
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 20         21    15577657   McDonald          732    France    Male   41
# 21         22    15597945   Dellucci          636     Spain  Female   32
# 22         23    15699309  Gerasimov          510     Spain  Female   38
# 23         24    15725737     Mosman          669    France    Male   46
# 24         25    15625047        Yen          846    France  Female   38
# 25         26    15738191    Maclean          577    France    Male   25
#
#     Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 20       8      0.0              2          1               1
# 21       8      0.0              2          1               0
# 22       4      0.0              1          1               0
# 23       3      0.0              2          0               1
# 24       5      0.0              1          1               1
# 25       3      0.0              2          0               1
#
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
old_customers_greater_50 = df[df.Age >= 50]

# %%
type(old_customers_greater_50)
# Out:
# pandas.core.frame.DataFrame

# %%
old_customers_greater_50
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 6             7    15592531     Bartlett          822    France    Male   50
# 16           17    15737452        Romeo          653   Germany    Male   58
# 41           42    15738148       Clarke          465    France  Female   51
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# ...         ...         ...          ...          ...       ...     ...  ...
# 9939       9940    15808971       Lajoie          693     Spain  Female   57
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9975       9976    15666295        Smith          610   Germany    Male   50
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
#
# ...

# %%
age_50 = df[df.Age > 50]

# %%
len(old_customers_greater_50)
# Out:
# 1395

# %%
len(df)
# Out:
# 10000

# %%
new_df = df[df.Age >= 50]

# %%
new_df.sort_values('Age')
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 6             7    15592531   Bartlett          822    France    Male   50
# 8029       8030    15732113    Butters          671     Spain    Male   50
# 8017       8018    15631406      Munro          459   Germany    Male   50
# 5086       5087    15667289  Henderson          719     Spain    Male   50
# 7974       7975    15722632    Dickson          716   Germany    Male   50
# ...         ...         ...        ...          ...       ...     ...  ...
# 3387       3388    15798024       Lori          537   Germany    Male   84
# 3033       3034    15578006        Yao          787    France  Female   85
# 2458       2459    15813303    Rearick          513     Spain    Male   88
# 6759       6760    15660878      T'ien          705    France    Male   92
# 6443       6444    15764927     Rogova          753    France    Male   92
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
new_df_Age_greater_50 = df[df.Age > 50]

# %%
new_df_Age_greater_50.head(5)
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 16         17    15737452    Romeo          653   Germany    Male   58
# 41         42    15738148   Clarke          465    France  Female   51
# 42         43    15687946  Osborne          556    France  Female   61
# 44         45    15684171  Bianchi          660     Spain  Female   61
# 58         59    15623944    T'ien          511     Spain  Female   66
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 16       1  132602.88              1          1               0
# 41       8  122522.32              1          0               0
# 42       2  117419.35              1          1               1
# 44       5  155931.11              1          1               1
# 58       4       0.00              1          1               0
#
#     EstimatedSalary  Exited  New Balance Random Column
# 16          5097.67       1    133602.88      Good Day
# ...

# %%
len(new_df_Age_greater_50)
# Out:
# 1261

# %%
Gender, Age

M, 21
M, 22
F, -
F, 23
M, 17

df['Age'].fillna(15)

# %%
df['Age'].fillna(10)
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1395 entries, 6 to 9991
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        1395 non-null   int64
#  1   CustomerId       1395 non-null   int64
#  2   Surname          1395 non-null   object
#  3   CreditScore      1395 non-null   int64
#  4   Geography        1395 non-null   object
#  5   Gender           1395 non-null   object
#  6   Age              1395 non-null   int64
#  7   Tenure           1395 non-null   int64
#  8   Balance          1395 non-null   float64
#  9   NumOfProducts    1395 non-null   int64
#  10  HasCrCard        1395 non-null   int64
#  11  IsActiveMember   1395 non-null   int64
#  12  EstimatedSalary  1395 non-null   float64
#  13  Exited           1395 non-null   int64
#  14  New Balance      1395 non-null   float64
#  15  Random Column    1395 non-null   object
# dtypes: float64(3), int64(9), object(4)
# ...

# %% [markdown]
# Remove Columns

# %%
new_df.pop('RowNumber')
# Out:
# 6          7
# 16        17
# 41        42
# 42        43
# 44        45
#         ...
# 9939    9940
# 9948    9949
# 9975    9976
# 9979    9980
# 9991    9992
# Name: RowNumber, Length: 1395, dtype: int64

# %%
new_df
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 6       15592531     Bartlett          822    France    Male   50       7
# 16      15737452        Romeo          653   Germany    Male   58       1
# 41      15738148       Clarke          465    France  Female   51       8
# 42      15687946      Osborne          556    France  Female   61       2
# 44      15684171      Bianchi          660     Spain  Female   61       5
# ...          ...          ...          ...       ...     ...  ...     ...
# 9939    15808971       Lajoie          693     Spain  Female   57       9
# 9948    15735078    Onwughara          724   Germany  Female   53       1
# 9975    15666295        Smith          610   Germany    Male   50       1
# 9979    15692664       Diribe          677    France  Female   58       1
# 9991    15769959  Ajuluchukwu          597    France  Female   53       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
new_df.head(5)
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 3512    15657779       Boylan          806     Spain    Male   18       3
# 1678    15569178    Kharlamov          570    France  Female   18       4
# 3517    15757821      Burgess          771     Spain    Male   18       1
# 9520    15673180  Onyekaozulu          727   Germany  Female   18       2
# 2021    15795519     Vasiliev          716   Germany  Female   18       3
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 3512       0.00              2          1               1         86994.54
# 1678   82767.42              1          1               0         71811.90
# 3517       0.00              2          0               0         41542.95
# 9520   93816.70              2          1               0        126172.11
# 2021  128743.80              1          0               0        197322.13
#
#       Exited
# 3512       0
# 1678       0
# 3517       0
# ...

# %%
new_df.pop('CustomerId')
# Out:
# 6       15592531
# 16      15737452
# 41      15738148
# 42      15687946
# 44      15684171
#           ...
# 9939    15808971
# 9948    15735078
# 9975    15666295
# 9979    15692664
# 9991    15769959
# Name: CustomerId, Length: 1395, dtype: int64

# %%
new_df.head(5)
# Out:
#      Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 6   Bartlett          822    France    Male   50       7       0.00
# 16     Romeo          653   Germany    Male   58       1  132602.88
# 41    Clarke          465    France  Female   51       8  122522.32
# 42   Osborne          556    France  Female   61       2  117419.35
# 44   Bianchi          660     Spain  Female   61       5  155931.11
#
#     NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 6               2          1               1         10062.80       0
# 16              1          1               0          5097.67       1
# 41              1          0               0        181297.65       1
# 42              1          1               1         94153.83       0
# 44              1          1               1        158338.39       0
#
#     New Balance Random Column
# 6       1000.00      Good Day
# 16    133602.88      Good Day
# 41    123522.32      Good Day
# ...

# %%
len(new_df_Age_greater_50)
# Out:
# 1261

# %%
new_df_Age_greater_50
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 16           17    15737452        Romeo          653   Germany    Male   58
# 41           42    15738148       Clarke          465    France  Female   51
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# 58           59    15623944        T'ien          511     Spain  Female   66
# ...         ...         ...          ...          ...       ...     ...  ...
# 9936       9937    15653037        Parks          609    France    Male   77
# 9939       9940    15808971       Lajoie          693     Spain  Female   57
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
#
# ...

# %%
new_df_Age_greater_50_1 = new_df_Age_greater_50.drop('RowNumber', axis=1)

# %%
new_df_Age_greater_50_1.head(5)
# Out:
#     CustomerId  Surname  CreditScore Geography  Gender  Age  Tenure  \
# 16    15737452    Romeo          653   Germany    Male   58       1
# 41    15738148   Clarke          465    France  Female   51       8
# 42    15687946  Osborne          556    France  Female   61       2
# 44    15684171  Bianchi          660     Spain  Female   61       5
# 58    15623944    T'ien          511     Spain  Female   66       4
#
#       Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 16  132602.88              1          1               0          5097.67
# 41  122522.32              1          0               0        181297.65
# 42  117419.35              1          1               1         94153.83
# 44  155931.11              1          1               1        158338.39
# 58       0.00              1          1               0          1643.11
#
#     Exited  New Balance Random Column
# 16       1    133602.88      Good Day
# 41       1    123522.32      Good Day
# ...

# %%
new_df_Age_greater_50.head(5)
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 16         17    15737452    Romeo          653   Germany    Male   58
# 41         42    15738148   Clarke          465    France  Female   51
# 42         43    15687946  Osborne          556    France  Female   61
# 44         45    15684171  Bianchi          660     Spain  Female   61
# 58         59    15623944    T'ien          511     Spain  Female   66
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 16       1  132602.88              1          1               0
# 41       8  122522.32              1          0               0
# 42       2  117419.35              1          1               1
# 44       5  155931.11              1          1               1
# 58       4       0.00              1          1               0
#
#     EstimatedSalary  Exited  New Balance Random Column
# 16          5097.67       1    133602.88      Good Day
# ...

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Balance'].apply(np.sqrt)
# Out:
# 0         0.000000
# 1       289.495872
# 2       399.575775
# 3         0.000000
# 4       354.275063
#            ...
# 9995      0.000000
# 9996    239.519540
# 9997      0.000000
# 9998    273.998741
# 9999    360.753087
# Name: Balance, Length: 10000, dtype: float64

# %%
df['SqRoot_Balance'] = df['Balance'].apply(np.sqrt)

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  New Balance Random Column  SqRoot_Balance
# 0        101348.88       1      1000.00      Good Day        0.000000
# ...

# %%
#Drops all the null values in Age column

df['Age'].dropna()
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df.dropna()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Concat & Merging

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, 
                  index=[0,1,2,3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']}, 
                  index=[4,5,6,7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
#frames = [df1,df2]

# %%
result = pd.concat([df1, df2])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
#  INNER JOIN , OUTER JOIN ,LEFT JOIN ,RIGHT

table1
cust_id, cust_name
1, shivam
2, ashish
3, prabhu
4, pratham

table2
cust_id, salary
2, 10000
3, 25000
5, 20000

output:
cust_id, cust_name, salary
inner join

2, ashish, 10000
3, prabhu, 25000


left join
1, shivam, -
2, ashish, 10000
3, prabhu, 25000
4, pratham, - 


right join
2, ashish, 10000
3, prabhu, 25000
5, - , 20000

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, )


df2 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'], 
                    'F': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C0', 'C3', 'C6', 'C7'], 
                    'G': ['D4', 'D5', 'D6', 'D7']}, )

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     E   F   C   G
# 0  A4  B4  C0  D4
# 1  A5  B5  C3  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
merge_df = pd.merge(df1, df2, on='C', how='inner')

# %%
merge_df
# Out:
#     A   B   C   D   E   F   G
# 0  A0  B0  C0  D0  A4  B4  D4
# 1  A3  B3  C3  D3  A5  B5  D5

# %%
merge_df = pd.merge(df1, df2, on='C', how='left')

# %%
merge_df
# Out:
#     A   B   C   D    E    F    G
# 0  A0  B0  C0  D0   A4   B4   D4
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2  NaN  NaN  NaN
# 3  A3  B3  C3  D3   A5   B5   D5

# %%
merge_df = pd.merge(df1, df2, on='C', how='right')

# %%
merge_df
# Out:
#      A    B   C    D   E   F   G
# 0   A0   B0  C0   D0  A4  B4  D4
# 1   A3   B3  C3   D3  A5  B5  D5
# 2  NaN  NaN  C6  NaN  A6  B6  D6
# 3  NaN  NaN  C7  NaN  A7  B7  D7

# %% [markdown]
# ## loc vs iloc

# %%
s = pd.Series(list("abcdef"), index=[49, 48, 47, 0, 1, 2]) 
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s.loc[0]    # value at index label 0
# Out:
# 'd'

# %%
s.iloc[3]
# Out:
# 'd'

# %%
s.iloc[0]   # value at index location 0
# Out:
# 'a'

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)
# Out:
# 49    a
# dtype: object

# %%
s.iloc[0:2]
# Out:
# 49    a
# 48    b
# dtype: object

# %% [markdown]
# ### What if you sort the Series

# %%
s = s.sort_index()

# %%
s
# Out:
# 0     d
# 1     e
# 2     f
# 47    c
# 48    b
# 49    a
# dtype: object

# %%
s.iloc[0]
# Out:
# 'd'

# %%
s.loc[0]    # value at index label 0
# Out:
# 'd'

# %%
s.iloc[0]   # value at index location 0
# Out:
# 'd'

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)
# Out:
# 0    d
# dtype: object
