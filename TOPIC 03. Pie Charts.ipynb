# %% [markdown]
# ## The Pie Chart
#
# To create a pie chart using matplotlib, refer to the pie`() function`.
#
# ```plt.pie(data)```
#
# where `data` is an array of data values that you want to plot.
#
# There are many other optional parameters that can pass to `plt.pie()`. Some of them include:
#
# - `explode` allows separating slices of a pie chart
# - `labels` is a list of strings that sets the label of each corresponding slice
# - `labeldistance` determines the radial distance at which pie labels are drawn (default is `1.1`)
# - `color` colors slices
# - `shadow` creates the shadow of a slice
# - `startangle` lets you choose the starting angle of a plot
# - `wedgeprops` lets you tune various slice parameters
# - `radius` sets the radius of the circle(by default, it is `1`)
#
# Let's create simple pie chart. Assume our data represents the result of a survey on a favorite programming language:

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.style.use('seaborn-white')
plt.rc('figure', figsize=(8, 6))

# %%
data=[33,52,12,17,42,48]
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x251c0f78280>,
#   <matplotlib.patches.Wedge at 0x251c0f78760>,
#   <matplotlib.patches.Wedge at 0x251c0f78c40>,
#   <matplotlib.patches.Wedge at 0x251c0f91160>,
#   <matplotlib.patches.Wedge at 0x251c0f91640>,
#   <matplotlib.patches.Wedge at 0x251c0f91b20>],
#  [Text(0.9609846208671619, 0.5352649423012844, ''),
#   Text(-0.26830517633078194, 1.0667766084584478, ''),
#   Text(-1.0374699238087908, 0.3655901492001418, ''),
#   Text(-1.0936147390894126, -0.11835033775362135, ''),
#   Text(-0.5790752388061366, -0.9352389362091464, ''),
#   Text(0.8129099283232034, -0.7410650770570452, '')])

# %% [markdown]
# ## Labels
#
# Adding labels to a pie chart is pretty straightforward just need to pass a list of strings with labels corresponding to the list of values:

# %%
labels=['Python','C','C++','PHP','Java','Ruby']

data=[33,52,12,17,42,48]
plt.pie(data, labels=labels)
plt.show()

# %% [markdown]
# ### Now let's customize the pie chart with adding a legend and title the whole graph.

# %%
labels=['Python','C','C++','PHP','Java','Ruby']

data=[33,52,12,17,42,48]
plt.pie(data, labels=labels)
plt.title("The result of programming languages survey")
plt.legend(labels)
plt.show()

# %%
labels=['Python','C','C++','PHP','Java','Ruby']

data=[33,52,12,17,42,48]
plt.pie(data, labels=labels)
plt.title("The result of programming languages survey")
plt.legend(labels, loc=2)
plt.show()

# %% [markdown]
# ## Explode
#
# The explode parameter in pie charts separates a slice from the main pie. To highlight some of the fractions, we need to pass a list of values to the explode parameter. The values determine how far we want to separate this category from the main pie.

# %%
labels=['Python','C','C++','PHP','Java','Ruby']
explode= [0,0.1,0,0,0,0]
data=[33,52,12,17,42,48]
plt.pie(data, labels=labels, explode=explode)
plt.title("The result of programming languages survey")
plt.legend(labels, loc=2)
plt.show()

# %% [markdown]
# ## Colors and shadows
#
# To make our graph even more illustrative, we can pass a list of colors to the color parameter and add a shadow underneath by setting the shadow to True:

# %%
colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']

labels=['Python','C','C++','PHP','Java','Ruby']
explode= [0,0.1,0,0,0,0]
data=[33,52,12,17,42,48]
plt.pie(data, labels=labels, explode=explode, shadow=True)
plt.title("The result of programming languages survey")
plt.legend(labels, loc=2)
plt.show()

# %% [markdown]
# ## Display the value
#
# The autopct parameter displays the percent value on the slices. If autopct is %.2f, then for each pie slice, the format string is %.2f, where %is a special character that tells when to type the value, f sets the result to be a floating-point type, and the .2 sets a limit to only 2 digits after the point.

# %%
colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']

labels=['Python','C','C++','PHP','Java','Ruby']
explode= [0,0.1,0,0,0,0]
data=[33,52,12,17,42,48]
plt.pie(data, labels=labels, explode=explode, autopct="%.1f%%")
plt.title("The result of programming languages survey")
plt.legend(labels, loc=2)
plt.show()

# %% [markdown]
# ## Starting angle
#
# By default, pie charts are plotted from the x-axis; slices are plotted counterclockwise:
#
# The startangle parameter lets us define the angle where we want to initiate our pie (the default angle is 0). You can choose whether you want to plot the slices counterclockwise by changing the counterclock parameter; it is True by default.
#
# Let's assume we want the slices to start at 90 degrees.

# %%
colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']

labels=['Python','C','C++','PHP','Java','Ruby']
explode= [0,0.1,0,0,0,0]
data=[33,52,12,17,42,48]
plt.pie(data, labels=labels, explode=explode, autopct="%.1f%%", startangle=45)
plt.title("The result of programming languages survey")
plt.legend(labels, loc=2)
plt.show()

# %% [markdown]
# ## The doughnut chart
#
# A doughnut chart is very similar to a pie chart. However, since a doughnut chart has an opening at the center, it makes slices look more like bars. Unfortunately, there is no specific method for plotting a doughnut chart in the matplotlib library. But we can use the wedgeprops parameter to define the width of the wedges.

# %%
plt.pie(data, 
        labels=labels, 
        colors=colors, 
        startangle=90, 
        wedgeprops={'width': 0.2})
plt.show()

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]

labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']

# %%
explode = [0, 0, 0, 0.1, 0]

# %%
plt.xkcd()
plt.pie(slices, labels=labels, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})

# explode - to emphasis on a cut
# shadow - to give a shadow to the chart
# startangle - start at a certain angle
# autopct - calculate percentages


plt.title('My Awesome Pie Chart')
plt.tight_layout()
# plt.savefig(r'plots/plot3-1.png')
plt.show()

# %% [markdown]
# # REVISION

# %%
from matplotlib import pyplot as plt
plt.style.use('seaborn-white')
plt.rc('figure', figsize=(8, 6))
data=[50,40,30,20,60,10]
plt.pie(data)
# Out:
# ([<matplotlib.patches.Wedge at 0x251c2519130>,
#   <matplotlib.patches.Wedge at 0x251c25196d0>,
#   <matplotlib.patches.Wedge at 0x251c2519bb0>,
#   <matplotlib.patches.Wedge at 0x251c11890d0>,
#   <matplotlib.patches.Wedge at 0x251c11895b0>,
#   <matplotlib.patches.Wedge at 0x251c1189a90>],
#  [Text(0.8063570573449376, 0.7481900133455492, ''),
#   Text(-0.5500000148652439, 0.9526279355804298, ''),
#   Text(-1.0999999999999988, -5.149471622296949e-08, ''),
#   Text(-0.8063570048069821, -0.7481900699679946, ''),
#   Text(0.40187524778204176, -1.023961076027855, ''),
#   Text(1.0877139352529008, -0.1639463176062465, '')])

# %%
labels=['math','english','hindi','science','computer','art']
data=[50,40,30,20,60,10]
plt.pie(data,labels=labels)
plt.title("All subject marks ")
plt.legend(labels)
plt.show()

# %%
color=['blue','green','black','red','grey','navyblue']
labels=['math','english','hindi','science','computer','art']
data=[50,40,30,20,60,10]
explode=[0,0,0,0,0.2,0]
plt.pie(data,labels=labels,explode=explode,autopct="%.1f%%",shadow=True)
plt.title("All subject marks ")
plt.legend(labels)
plt.show()

# %%
color=['blue','green','black','red','grey','navyblue']
labels=['math','english','hindi','science','computer','art']
data=[50,40,30,20,60,10]
explode=[0,0,0,0,0.2,0]
plt.pie(data,labels=labels,explode=explode,autopct="%.1f%%",shadow=True,startangle=45)
plt.title("All subject marks ")
plt.legend(labels)
plt.show()

# %%
color=['blue','green','black','red','grey','navyblue']
labels=['math','english','hindi','science','computer','art']
data=[50,40,30,20,60,10]
explode=[0,0,0,0,0.2,0]
plt.pie(data,labels=labels,explode=explode,autopct="%.1f%%",shadow=True,startangle=180)
plt.title("All subject marks ")
plt.legend(labels)
plt.show()

# %%
plt.pie(data, 
        labels=labels, 
        colors=colors, 
        startangle=180, 
        wedgeprops={'width': 0.2})
plt.show()

# %%
labels=['math','english','hindi','science','computer']
data=[50,40,30,20,60]
explode = [0, 0, 0, 0.1, 0]

# %%
plt.xkcd()
plt.pie(slices, labels=labels, explode=explode, shadow=True,
        startangle=90, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})
plt.tight_layout()
plt.show()
